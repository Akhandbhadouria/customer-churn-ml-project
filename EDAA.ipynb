# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("Bank_Churn.csv")

# %% [markdown]
# ABOUT DATA

# %%
print("shape :", df.shape)
print("Data Types: \n",df.dtypes)


print("\nMissing Values\n",df.isnull().sum())

print("Duplicate Rows:", df.duplicated().sum())
# Out:
# shape : (10000, 13)
# Data Types:
#  CustomerId           int64
# Surname             object
# CreditScore          int64
# Geography           object
# Gender              object
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object
#
# Missing Values
#  CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64
# Duplicate Rows: 0

# %% [markdown]
# ABOUT TARGET

# %%
churn_rate = df["Exited"].value_counts(normalize=True) * 100
print("\nChurn Percentage:\n", churn_rate)

sns.set(style="darkgrid")
plt.rcParams["figure.figsize"] = (8,5)

plt.figure()
sns.countplot(x="Exited", data=df)
plt.show()
# Out:
# Churn Percentage:
#  Exited
# 0    79.63
# 1    20.37
# Name: proportion, dtype: float64

# %%
plt.figure()
sns.countplot(x="Gender", hue="Exited", data=df)
plt.title("Gender vs Churn")
plt.show()

# %%
plt.figure(figsize=(10,6))
corr = df.select_dtypes(include=np.number).corr()
sns.heatmap(corr, annot=True)
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# OUTLIER DETECTION

# %%
n_col = ["Age", "Balance", "EstimatedSalary", "CreditScore"]
for col in n_col:
    plt.figure()
    sns.boxplot(y=df[col])
    plt.title(f"outlier cheacking for -{col}")
    plt.show

# %%
plt.figure()
sns.histplot(df["Balance"], bins=30, kde=True)
plt.title("Balance Distribution")
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv("Bank_Churn.csv")
print("shape :", df.shape)
print("Data Types: \n",df.dtypes)
print("\nMissing Values\n",df.isnull().sum())
print("Duplicate Rows:", df.duplicated().sum())
churn_rate = df["Exited"].value_counts(normalize=True) * 100
print("\nChurn Percentage:\n", churn_rate)
sns.set(style="darkgrid")
plt.rcParams["figure.figsize"] = (8,5)
plt.figure()
sns.countplot(x="Exited", data=df)
plt.show()
plt.figure()
sns.countplot(x="Gender", hue="Exited", data=df)
plt.title("Gender vs Churn")
plt.show()
plt.figure(figsize=(10,6))
corr = df.select_dtypes(include=np.number).corr()
sns.heatmap(corr, annot=True)
plt.title("Correlation Heatmap")
plt.show()
n_col = ["Age", "Balance", "EstimatedSalary", "CreditScore"]
for col in n_col:
    plt.figure()
    sns.boxplot(y=df[col])
    plt.title(f"outlier cheacking for -{col}")
    plt.show()
plt.figure()
sns.histplot(df["Balance"], bins=30, kde=True)
plt.title("Balance Distribution")
plt.show()
